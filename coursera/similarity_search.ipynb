# %%
# !pip install sentence-transformers==4.1.0

# %%
import math

import numpy as np
import scipy
import torch
from sentence_transformers import SentenceTransformer
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 6
#       4 import scipy
#       5 import torch
# ----> 6 from sentence_transformers import SentenceTransformer
#
# File ~\anaconda3\envs\langchain\Lib\site-packages\sentence_transformers\__init__.py:14
#       7 import os
#       9 from sentence_transformers.backend import (
#      10     export_dynamic_quantized_onnx_model,
#      11     export_optimized_onnx_model,
#      12     export_static_quantized_openvino_model,
#      13 )
# ---> 14 from sentence_transformers.cross_encoder import (
#      15     CrossEncoder,
#      16     CrossEncoderModelCardData,
#      17     CrossEncoderTrainer,
#      18     CrossEncoderTrainingArguments,
#      19 )
#      20 from sentence_transformers.datasets import ParallelSentencesDataset, SentencesDataset
# ...
